# %% [markdown]
# <a href="https://colab.research.google.com/github/VladislavVaSAndreev/HW9_python/blob/main/Hw_Sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Библиотека для работы с табличными данными
import pandas as pd

# %%
# Прочтем файл .csv с помощью библиотеки pandas
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# Задача 40: Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
df.query ('population > 0 & population < 500') [['median_house_value']]
# Out:
#        median_house_value
# 2                 85700.0
# 7                 48500.0
# 17                25000.0
# 19                27500.0
# 21                59200.0
# ...                   ...
# 16944            130600.0
# 16951             67500.0
# 16969             60000.0
# 16982            107000.0
# 16994             76100.0
#
# [1601 rows x 1 columns]

# %% [markdown]
# Задача 42: Узнать какая максимальная households в зоне минимального значения population.

# %%
apr = df['population'].min()*1.25
df.query(f'population < {apr}') [['households']].max()
# Out:
# households    4.0
# dtype: float64
